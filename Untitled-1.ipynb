# %%
using Plots, Distributions

# %%
L = Normal(1, 1)
# Out:
# Normal{Float64}(μ=1.0, σ=1.0)

# %%
plot(x->pdf(Normal(1, 1), x))

# %%
function para(x)
    x->cos(x)
end
# Out:
# para (generic function with 1 method)

# %%
y = pdf(Normal(1, 1), x)
# Out:
# MethodError: pdf(::Normal{Float64}, ::LinRange{Float64, Int64}) is ambiguous. Candidates:
#
#   pdf(d::Distribution{ArrayLikeVariate{N}}, x::AbstractArray{<:Real, M}) where {N, M} in Distributions at /home/hezy/.julia/packages/Distributions/bQ6Gj/src/common.jl:275
#
#   pdf(d::UnivariateDistribution, X::AbstractArray) in Distributions at deprecated.jl:70
#
# Possible fix, define
#
#   pdf(::UnivariateDistribution, ::AbstractArray{T, M} where T<:Real) where M
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ Untitled-1.ipynb:1
